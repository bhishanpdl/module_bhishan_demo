# %% [markdown]
# # Example

# %%
# my local module # needs: scipy, statsmodels, scikit-learn, plotly
import sys
sys.path.append(r'C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan')
sys.path.append(r'C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan')
import bhishan
from bhishan import bp

# %%
import seaborn as sns

df = sns.load_dataset('tips')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.bp.plot_num('tip')
