# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Numerical-and-Categorical-Plots" data-toc-modified-id="Numerical-and-Categorical-Plots-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Numerical and Categorical Plots</a></span></li><li><span><a href="#Time-Taken" data-toc-modified-id="Time-Taken-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Time Taken</a></span></li></ul></div>

# %% [markdown]
# # Imports

# %%
import time

time_start_notebook = time.time()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = 100

# %load_ext autoreload
# %load_ext watermark

# %autoreload 2
# %watermark -a "Bhishan Poudel" -d -v -m
# %watermark -iv
# Out:
# Author: Bhishan Poudel
#
# Python implementation: CPython
# Python version       : 3.11.7
# IPython version      : 8.20.0
#
# Compiler    : MSC v.1937 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 141 Stepping 1, GenuineIntel
# CPU cores   : 16
# Architecture: 64bit
#
# seaborn   : 0.13.0
# pandas    : 1.5.3
# numpy     : 1.26.3
# matplotlib: 3.8.2

# %%
# my local library
import sys
from pathlib import Path
import platform

if platform.system() == 'Windows':
    p = Path("~/OneDrive - AmerisourceBergen(ABC)/bhishan").expanduser()
elif platform.system() == 'Darwin':
    p = Path.home() / "Dropbox/a00_Bhishan_Modules"
sys.path.append(str(p))
from bhishan import bp

# %% [markdown]
# # Load data

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Numerical and Categorical Plots

# %%
df = titanic

# %%
df['age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
# df.bp.plot_num('age',print_=True,ms='seaborn-darkgrid')
df.bp.plot_num(num='age',print_=True,ms='dark_background',
               kw={'xlim00':(0,60)},

              )
# Out:
#      count       mean        std   min     25%   50%   75%   max
# age  714.0  29.699118  14.526497  0.42  20.125  28.0  38.0  80.0

# %%
# !ls /Users/poudel/Dropbox/a00_Bhishan_Modules/bhishan/bhishan/mpl_styles
# Out:
# ls: cannot access '/Users/poudel/Dropbox/a00_Bhishan_Modules/bhishan/bhishan/mpl_styles': No such file or directory

# %%
cat = 'pclass'
    
fig,ax = plt.subplots()
df[cat].value_counts().plot.bar()
    
ax.get_xticklabels()
# Out:
# [Text(0, 0, '3'), Text(1, 0, '1'), Text(2, 0, '2')]

# %%
# WARNING: This is wrong way.
df.bp.plot_cat('pclass',ms=-1,
               kw={'xticks0': [0,1,2],
                   'xticklabels0': ['First','Second','Third']}
              )
print("This is wrong")
plt.title("this is wrong labels")
# Out:
# This is wrong
# Text(0.5, 1.0, 'this is wrong labels')

# %%
# We must know the correct xlabels
df.bp.plot_cat('pclass',ms=-1,
               kw={'xticks0': [3,1,2],
                   'xticklabels0': ['Third','First','Second']
                  })

# %%
df.bp.plot_num_num('age','fare',ms=-1,rot=90,figsize=(12,12))

# %%
df.bp.plot_num_num('age','fare',ms=-1,rot=90,figsize=(12,12),
                   kw={'xticks01':range(0,600,50)},
                   )

# %%
df.bp.plot_cat('pclass',ms=-1)

# %%
df.bp.plot_num_num('age','fare',xticks1=range(0,90,10),ms=-1,
                   xticks2=range(0,600,50),rot=90,figsize=(12,12))

# %%
df.bp.plot_num_cat('age','survived',kw={'xlim10':[0,50]})

# %%
df.bp.plot_cat_num('pclass','age',save=True,show=True,ms='fast')
# Out:
# C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan\plot_num_cat.py:858: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan\plot_num_cat.py:859: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan\plot_num_cat.py:861: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#
# C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan\plot_num_cat.py:861: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan\plot_num_cat.py:865: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan\plot_num_cat.py:866: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
df.bp.plot_cat_cat('pclass','survived',save=True,show=True,ms=-1)
# Out:
# ==================================================
# Feature: **pclass**
# Overall Count:
#     3: 55.11%
#     1: 24.24%
#     2: 20.65%
#
# Total  **survived_1** distribution:
#     1: 39.77%
#     3: 34.8%
#     2: 25.44%
#
# Per pclass  **survived_1** distribution:
#     1: 62.96%
#     2: 47.28%
#     3: 24.24%

# %% [markdown]
# # Time Taken

# %%
time_taken = time.time() - time_start_notebook
h,m = divmod(time_taken,60*60)
print('Time taken to run whole notebook: {:.0f} hr '\
      '{:.0f} min {:.0f} secs'.format(h, *divmod(m,60)))
# Out:
# Time taken to run whole notebook: 0 hr 0 min 18 secs
