# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Using-plotly-api-in-module-bhishan" data-toc-modified-id="Using-plotly-api-in-module-bhishan-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Using plotly api in module bhishan</a></span></li><li><span><a href="#Correlation" data-toc-modified-id="Correlation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Correlation</a></span></li><li><span><a href="#Partial-Correlation" data-toc-modified-id="Partial-Correlation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Partial Correlation</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Outliers</a></span></li><li><span><a href="#Kernel-Density" data-toc-modified-id="Kernel-Density-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Kernel Density</a></span></li></ul></div>

# %% [markdown]
# # Description
# This is an example tutorial to use my module bhishan for the plotly
# extension for pandas.

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext autoreload
# %load_ext watermark

# %autoreload 2
# %watermark -a "Bhishan Poudel" -d -v -m
# %watermark -iv
# Out:
# Author: Bhishan Poudel
#
# Python implementation: CPython
# Python version       : 3.11.7
# IPython version      : 8.20.0
#
# Compiler    : MSC v.1937 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 141 Stepping 1, GenuineIntel
# CPU cores   : 16
# Architecture: 64bit
#
# numpy     : 1.26.3
# seaborn   : 0.13.0
# pandas    : 1.5.3
# matplotlib: 3.8.2

# %%
# my local library
import sys
from pathlib import Path
import platform

if platform.system() == 'Windows':
    p = Path("~/OneDrive - AmerisourceBergen(ABC)/bhishan").expanduser()
elif platform.system() == 'Darwin':
    p = Path.home() / "Dropbox/a00_Bhishan_Modules"
sys.path.append(str(p))
from bhishan import bp

# %% [markdown]
# # Using plotly api in module bhishan

# %%
# print(sns.get_dataset_names())

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Correlation

# %%
df.bp.plot_corr(xrot=0)

# %%
df.bp.plot_corr(target='survived')

# %%
target = 'survived'
df_few_cols = df[['age','fare']]
df_few_cols.merge(df[target],left_index=True,right_index=True)\
           .bp.plot_corr()

# %%
df.bp.plot_corr_style()
# Out:
# <style type="text/css">
# #T_18756 th {
#   font-size: 7pt;
# }
# #T_18756 td {
#   padding: 0em 0em;
# }
# #T_18756 th:hover {
#   font-size: 12pt;
# }
# #T_18756 tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_18756_row0_col0, #T_18756_row1_col1, #T_18756_row2_col2, #T_18756_row3_col3, #T_18756_row4_col4, #T_18756_row5_col5, #T_18756_row6_col6, #T_18756_row7_col7 {
#   background-color: #053061;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row0_col1 {
#   background-color: #bf3338;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row0_col2 {
#   background-color: #f5a886;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row0_col3 {
#   background-color: #f7b799;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row0_col4 {
#   background-color: #fcdecd;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row0_col5, #T_18756_row5_col0 {
#   background-color: #eff3f5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row0_col6, #T_18756_row1_col5, #T_18756_row2_col1, #T_18756_row3_col7, #T_18756_row4_col7, #T_18756_row5_col1, #T_18756_row6_col0, #T_18756_row7_col3, #T_18756_row7_col4 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row0_col7 {
#   background-color: #de735c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row1_col0, #T_18756_row6_col4 {
#   background-color: #be3036;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row1_col2 {
#   background-color: #b72230;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row1_col3 {
#   background-color: #fdddcb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row1_col4 {
#   background-color: #fac8af;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row1_col6, #T_18756_row2_col7, #T_18756_row5_col2 {
#   background-color: #fcdfcf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row1_col7 {
#   background-color: #fae7dc;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row2_col0 {
#   background-color: #da6853;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row2_col3 {
#   background-color: #870a24;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row2_col4 {
#   background-color: #bd2d35;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row2_col5 {
#   background-color: #f7b99c;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row2_col6 {
#   background-color: #f9f0eb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row3_col0 {
#   background-color: #f8bda1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row3_col1, #T_18756_row4_col0, #T_18756_row6_col1 {
#   background-color: #fce0d0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row3_col2 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row3_col4, #T_18756_row4_col3 {
#   background-color: #bddbea;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row3_col5 {
#   background-color: #f9efe9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row3_col6 {
#   background-color: #d86551;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row4_col1 {
#   background-color: #fbd0b9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row4_col2 {
#   background-color: #e48066;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row4_col5 {
#   background-color: #f5f6f7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row4_col6 {
#   background-color: #c2383a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row5_col3 {
#   background-color: #f9ebe3;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row5_col4, #T_18756_row7_col2 {
#   background-color: #f7f5f4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row5_col6 {
#   background-color: #e17860;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row5_col7 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row6_col2 {
#   background-color: #e9f0f4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row6_col3 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row6_col5, #T_18756_row7_col0 {
#   background-color: #e27b62;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row6_col7 {
#   background-color: #c5dfec;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row7_col1 {
#   background-color: #faeae1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row7_col5 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_18756_row7_col6 {
#   background-color: #c2ddec;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# </style>
# <table id="T_18756">
#   <caption>Hover to magify</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18756_level0_col0" class="col_heading level0 col0" >survived</th>
#       <th id="T_18756_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_18756_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_18756_level0_col3" class="col_heading level0 col3" >sibsp</th>
#       <th id="T_18756_level0_col4" class="col_heading level0 col4" >parch</th>
#       <th id="T_18756_level0_col5" class="col_heading level0 col5" >fare</th>
#       <th id="T_18756_level0_col6" class="col_heading level0 col6" >adult_male</th>
#       <th id="T_18756_level0_col7" class="col_heading level0 col7" >alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18756_level0_row0" class="row_heading level0 row0" >survived</th>
#       <td id="T_18756_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_18756_row0_col1" class="data row0 col1" >-0.34</td>
#       <td id="T_18756_row0_col2" class="data row0 col2" >-0.08</td>
#       <td id="T_18756_row0_col3" class="data row0 col3" >-0.04</td>
#       <td id="T_18756_row0_col4" class="data row0 col4" >0.08</td>
#       <td id="T_18756_row0_col5" class="data row0 col5" >0.26</td>
#       <td id="T_18756_row0_col6" class="data row0 col6" >-0.56</td>
#       <td id="T_18756_row0_col7" class="data row0 col7" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_18756_level0_row1" class="row_heading level0 row1" >pclass</th>
#       <td id="T_18756_row1_col0" class="data row1 col0" >-0.34</td>
#       <td id="T_18756_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_18756_row1_col2" class="data row1 col2" >-0.37</td>
#       <td id="T_18756_row1_col3" class="data row1 col3" >0.08</td>
#       <td id="T_18756_row1_col4" class="data row1 col4" >0.02</td>
#       <td id="T_18756_row1_col5" class="data row1 col5" >-0.55</td>
#       <td id="T_18756_row1_col6" class="data row1 col6" >0.09</td>
#       <td id="T_18756_row1_col7" class="data row1 col7" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_18756_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_18756_row2_col0" class="data row2 col0" >-0.08</td>
#       <td id="T_18756_row2_col1" class="data row2 col1" >-0.37</td>
#       <td id="T_18756_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_18756_row2_col3" class="data row2 col3" >-0.31</td>
#       <td id="T_18756_row2_col4" class="data row2 col4" >-0.19</td>
#       <td id="T_18756_row2_col5" class="data row2 col5" >0.10</td>
#       <td id="T_18756_row2_col6" class="data row2 col6" >0.28</td>
#       <td id="T_18756_row2_col7" class="data row2 col7" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_18756_level0_row3" class="row_heading level0 row3" >sibsp</th>
#       <td id="T_18756_row3_col0" class="data row3 col0" >-0.04</td>
#       <td id="T_18756_row3_col1" class="data row3 col1" >0.08</td>
#       <td id="T_18756_row3_col2" class="data row3 col2" >

# %%
# df.bp.plot_corr_sns()

# %%
df.corr().style.apply(lambda x: ["background: salmon" if  (abs(v) > 0.5 and v!=1) else "" for v in x], axis = 1)
# Out:
# C:\Users\a126291\AppData\Local\Temp\ipykernel_27440\3549006802.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <style type="text/css">
# #T_d66d8_row0_col6, #T_d66d8_row1_col5, #T_d66d8_row3_col7, #T_d66d8_row4_col7, #T_d66d8_row5_col1, #T_d66d8_row6_col0, #T_d66d8_row7_col3, #T_d66d8_row7_col4 {
#   background: salmon;
# }
# </style>
# <table id="T_d66d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d66d8_level0_col0" class="col_heading level0 col0" >survived</th>
#       <th id="T_d66d8_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_d66d8_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_d66d8_level0_col3" class="col_heading level0 col3" >sibsp</th>
#       <th id="T_d66d8_level0_col4" class="col_heading level0 col4" >parch</th>
#       <th id="T_d66d8_level0_col5" class="col_heading level0 col5" >fare</th>
#       <th id="T_d66d8_level0_col6" class="col_heading level0 col6" >adult_male</th>
#       <th id="T_d66d8_level0_col7" class="col_heading level0 col7" >alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d66d8_level0_row0" class="row_heading level0 row0" >survived</th>
#       <td id="T_d66d8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d66d8_row0_col1" class="data row0 col1" >-0.338481</td>
#       <td id="T_d66d8_row0_col2" class="data row0 col2" >-0.077221</td>
#       <td id="T_d66d8_row0_col3" class="data row0 col3" >-0.035322</td>
#       <td id="T_d66d8_row0_col4" class="data row0 col4" >0.081629</td>
#       <td id="T_d66d8_row0_col5" class="data row0 col5" >0.257307</td>
#       <td id="T_d66d8_row0_col6" class="data row0 col6" >-0.557080</td>
#       <td id="T_d66d8_row0_col7" class="data row0 col7" >-0.203367</td>
#     </tr>
#     <tr>
#       <th id="T_d66d8_level0_row1" class="row_heading level0 row1" >pclass</th>
#       <td id="T_d66d8_row1_col0" class="data row1 col0" >-0.338481</td>
#       <td id="T_d66d8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d66d8_row1_col2" class="data row1 col2" >-0.369226</td>
#       <td id="T_d66d8_row1_col3" class="data row1 col3" >0.083081</td>
#       <td id="T_d66d8_row1_col4" class="data row1 col4" >0.018443</td>
#       <td id="T_d66d8_row1_col5" class="data row1 col5" >-0.549500</td>
#       <td id="T_d66d8_row1_col6" class="data row1 col6" >0.094035</td>
#       <td id="T_d66d8_row1_col7" class="data row1 col7" >0.135207</td>
#     </tr>
#     <tr>
#       <th id="T_d66d8_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_d66d8_row2_col0" class="data row2 col0" >-0.077221</td>
#       <td id="T_d66d8_row2_col1" class="data row2 col1" >-0.369226</td>
#       <td id="T_d66d8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d66d8_row2_col3" class="data row2 col3" >-0.308247</td>
#       <td id="T_d66d8_row2_col4" class="data row2 col4" >-0.189119</td>
#       <td id="T_d66d8_row2_col5" class="data row2 col5" >0.096067</td>
#       <td id="T_d66d8_row2_col6" class="data row2 col6" >0.280328</td>
#       <td id="T_d66d8_row2_col7" class="data row2 col7" >0.198270</td>
#     </tr>
#     <tr>
#       <th id="T_d66d8_level0_row3" class="row_heading level0 row3" >sibsp</th>
#       <td id="T_d66d8_row3_col0" class="data row3 col0" >-0.035322</td>
#       <td id="T_d66d8_row3_col1" class="data row3 col1" >0.083081</td>
#       <td id="T_d66d8_row3_col2" class="data row3 col2" >-0.308247</td>
#       <td id="T_d66d8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d66d8_row3_col4" class="data row3 col4" >0.414838</td>
#       <td id="T_d66d8_row3_col5" class="data row3 col5" >0.159651</td>
#       <td id="T_d66d8_row3_col6" class="data row3 col6" >-0.253586</td>
#       <td id="T_d66d8_row3_col7" class="data row3 col7" >-0.584471</td>
#     </tr>
#     <tr>
#       <th id="T_d66d8_level0_row4" class="row_heading level0 row4" >parch</th>
#       <td id="T_d66d8_row4_col0" class="data row4 col0" >0.081629</td>
#       <td id="T_d66d8_row4_col1" class="data row4 col1" >0.018443</td>
#       <td id="T_d66d8_row4_col2" class="data row4 col2" >-0.189119</td>
#       <td id="T_d66d8_row4_col3" class="data row4 col3" >0.414838</td>
#       <td id="T_d66d8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_d66d8_row4_col5" class="data row4 col5" >0.216225</td>
#       <td id="T_d66d8_row4_col6" class="data row4 col6" >-0.349943</td>
#       <td id="T_d66d8_row4_col7" class="data row4 col7" >-0.583398</td>
#     </tr>
#     <tr>
#       <th id="T_d66d8_level0_row5" class="row_heading level0 row5" >fare</th>
#       <td id="T_d66d8_row5_col0" class="data row5 col0" >0.257307</td>
#       <td id="T_d66d8_row5_col1" class="data row5 col1" >-0.549500</td>
#       <td id="T_d66d8_row5_col2" class="data row5 col2" >0.096067</td>
#       <td id="T_d66d8_row5_col3" class="data row5 col3" >0.159651</td>
#       <td id="T_d66d8_row5_col4" class="data row5 col4" >0.216225</td>
#       <td id="T_d66d8_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_d66d8_row5_col6" class="data row5 col6" >-0.182024</td>
#       <td id="T_d66d8_row5_col7" class="data row5 col7" >-0.271832</td>
#     </tr>
#     <tr>
#       <th id="T_d66d8_level0_row6" class="row_heading level0 row6" >adult_male</th>
#       <td id="T_d66d8_row6_col0" class="data row6 col0" >-0.557080</td>
#       <td id="T_d66d8_row6_col1" class="data row6 col1" >0.094035</td>
#       <td id="T_d66d8_row6_col2" class="data row6 col2" >0.280328</td>
#       <td id="T_d66d8_row6_col3" class="data row6 col3" >-0.253586</td>
#       <td id="T_d66d8_row6_col4" class="data row6 col4" >-0.349943</td>
#       <td id="T_d66d8_row6_col5" class="data row6 col5" >-0.182024</td>
#       <td id="T_d66d8_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_d66d8_row6_col7" class="data row6 col7" >0.404744</td>
#     </tr>
#     <tr>
#       <th id="T_d66d8_level0_row7" class="row_heading level0 row7" >alone</th>
#       <td id="T_d66d8_row7_col0" class="data row7 col0" >-0.203367</td>
#       <td id="T_d66d8_row7_col1" class="data row7 col1" >0.135207</td>
#       <td id="T_d66d8_row7_col2" class="data row7 col2" >0.198270</td>
#       <td id="T_d66d8_row7_col3" class="data row7 col3" >-0.584471</td>
#       <td id="T_d66d8_row7_col4" class="data row7 col4" >-0.583398</td>
#       <td id="T_d66d8_row7_col5" class="data row7 col5" >-0.271832</td>
#       <td id="T_d66d8_row7_col6" class="data row7 col6" >0.404744</td>
#       <td id="T_d66d8_row7_col7" class="data row7 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.bp.corr_high(thr=0.5,disp=True)
# Out:
# cols_high_corr = ['parch', 'alone', 'fare', 'sibsp', 'pclass', 'survived', 'adult_male']
# cols_high_corr1 = ['fare', 'survived', 'parch', 'alone']
# cols_high_corr2 = ['pclass', 'adult_male', 'alone', 'sibsp']
# cols_high_corr_drop = ['fare', 'parch', 'survived']
# C:\Users\a126291\OneDrive - AmerisourceBergen(ABC)\bhishan\bhishan\ds_corr_outliers.py:144: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <style type="text/css">
# #T_3ca04_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3ca04_row1_col2 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_3ca04_row2_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_3ca04_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_3ca04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ca04_level0_col0" class="col_heading level0 col0" >feature1</th>
#       <th id="T_3ca04_level0_col1" class="col_heading level0 col1" >feature2</th>
#       <th id="T_3ca04_level0_col2" class="col_heading level0 col2" >corr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ca04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ca04_row0_col0" class="data row0 col0" >fare</td>
#       <td id="T_3ca04_row0_col1" class="data row0 col1" >pclass</td>
#       <td id="T_3ca04_row0_col2" class="data row0 col2" >-0.549500</td>
#     </tr>
#     <tr>
#       <th id="T_3ca04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ca04_row1_col0" class="data row1 col0" >survived</td>
#       <td id="T_3ca04_row1_col1" class="data row1 col1" >adult_male</td>
#       <td id="T_3ca04_row1_col2" class="data row1 col2" >-0.557080</td>
#     </tr>
#     <tr>
#       <th id="T_3ca04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ca04_row2_col0" class="data row2 col0" >parch</td>
#       <td id="T_3ca04_row2_col1" class="data row2 col1" >alone</td>
#       <td id="T_3ca04_row2_col2" class="data row2 col2" >-0.583398</td>
#     </tr>
#     <tr>
#       <th id="T_3ca04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3ca04_row3_col0" class="data row3 col0" >alone</td>
#       <td id="T_3ca04_row3_col1" class="data row3 col1" >sibsp</td>
#       <td id="T_3ca04_row3_col2" class="data row3 col2" >-0.584471</td>
#     </tr>
#   </tbody>
# </table>

# %%
cols_high_corr_drop = ['fare', 'parch', 'survived']

# %%
df1 = df.drop(cols_high_corr_drop,axis=1)
df1.corr(numeric_only=True)
# Out:
#               pclass       age     sibsp  adult_male     alone
# pclass      1.000000 -0.369226  0.083081    0.094035  0.135207
# age        -0.369226  1.000000 -0.308247    0.280328  0.198270
# sibsp       0.083081 -0.308247  1.000000   -0.253586 -0.584471
# adult_male  0.094035  0.280328 -0.253586    1.000000  0.404744
# alone       0.135207  0.198270 -0.584471    0.404744  1.000000

# %% [markdown]
# # Partial Correlation

# %%
df.bp.partial_corr(thr=0.3,disp=True)
# Out:
# <style type="text/css">
# #T_6583a_row1_col2, #T_6583a_row2_col1 {
#   background: salmon;
# }
# </style>
# <table id="T_6583a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6583a_level0_col0" class="col_heading level0 col0" >survived</th>
#       <th id="T_6583a_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_6583a_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_6583a_level0_col3" class="col_heading level0 col3" >sibsp</th>
#       <th id="T_6583a_level0_col4" class="col_heading level0 col4" >parch</th>
#       <th id="T_6583a_level0_col5" class="col_heading level0 col5" >fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6583a_level0_row0" class="row_heading level0 row0" >survived</th>
#       <td id="T_6583a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6583a_row0_col1" class="data row0 col1" >0.115371</td>
#       <td id="T_6583a_row0_col2" class="data row0 col2" >0.111542</td>
#       <td id="T_6583a_row0_col3" class="data row0 col3" >-0.028674</td>
#       <td id="T_6583a_row0_col4" class="data row0 col4" >0.082447</td>
#       <td id="T_6583a_row0_col5" class="data row0 col5" >0.301210</td>
#     </tr>
#     <tr>
#       <th id="T_6583a_level0_row1" class="row_heading level0 row1" >pclass</th>
#       <td id="T_6583a_row1_col0" class="data row1 col0" >0.115371</td>
#       <td id="T_6583a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6583a_row1_col2" class="data row1 col2" >0.571910</td>
#       <td id="T_6583a_row1_col3" class="data row1 col3" >0.306844</td>
#       <td id="T_6583a_row1_col4" class="data row1 col4" >0.173285</td>
#       <td id="T_6583a_row1_col5" class="data row1 col5" >-0.315652</td>
#     </tr>
#     <tr>
#       <th id="T_6583a_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_6583a_row2_col0" class="data row2 col0" >0.111542</td>
#       <td id="T_6583a_row2_col1" class="data row2 col1" >0.571910</td>
#       <td id="T_6583a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6583a_row2_col3" class="data row2 col3" >-0.192800</td>
#       <td id="T_6583a_row2_col4" class="data row2 col4" >-0.095105</td>
#       <td id="T_6583a_row2_col5" class="data row2 col5" >0.392652</td>
#     </tr>
#     <tr>
#       <th id="T_6583a_level0_row3" class="row_heading level0 row3" >sibsp</th>
#       <td id="T_6583a_row3_col0" class="data row3 col0" >-0.028674</td>
#       <td id="T_6583a_row3_col1" class="data row3 col1" >0.306844</td>
#       <td id="T_6583a_row3_col2" class="data row3 col2" >-0.192800</td>
#       <td id="T_6583a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_6583a_row3_col4" class="data row3 col4" >0.324787</td>
#       <td id="T_6583a_row3_col5" class="data row3 col5" >0.211403</td>
#     </tr>
#     <tr>
#       <th id="T_6583a_level0_row4" class="row_heading level0 row4" >parch</th>
#       <td id="T_6583a_row4_col0" class="data row4 col0" >0.082447</td>
#       <td id="T_6583a_row4_col1" class="data row4 col1" >0.173285</td>
#       <td id="T_6583a_row4_col2" class="data row4 col2" >-0.095105</td>
#       <td id="T_6583a_row4_col3" class="data row4 col3" >0.324787</td>
#       <td id="T_6583a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_6583a_row4_col5" class="data row4 col5" >0.199136</td>
#     </tr>
#     <tr>
#       <th id="T_6583a_level0_row5" class="row_heading level0 row5" >fare</th>
#       <td id="T_6583a_row5_col0" class="data row5 col0" >0.301210</td>
#       <td id="T_6583a_row5_col1" class="data row5 col1" >-0.315652</td>
#       <td id="T_6583a_row5_col2" class="data row5 col2" >0.392652</td>
#       <td id="T_6583a_row5_col3" class="data row5 col3" >0.211403</td>
#       <td id="T_6583a_row5_col4" class="data row5 col4" >0.199136</td>
#       <td id="T_6583a_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.bp.partial_corr(['fare','age'])
# Out:
#           fare       age
# fare  1.000000  0.096067
# age   0.096067  1.000000

# %% [markdown]
# # Outliers

# %%
ser_outliers = df.bp.outliers_tukey('age')
ser_outliers
# Out:
#       age
# 33   66.0
# 54   65.0
# 96   71.0
# 116  70.5
# 280  65.0
# 456  65.0
# 493  71.0
# 630  80.0
# 672  70.0
# 745  70.0
# 851  74.0

# %%
col = 'age'
df1 = df.dropna(subset=[col]).reset_index(drop=True)
idx_outliers, val_outliers = df1.bp.outliers_kde(col)
df1.loc[idx_outliers,[col]]
# Out:
#       age
# 498  80.0
# 679  74.0
# 74   71.0
# 393  71.0
# 91   70.5
# 531  70.0
# 592  70.0
# 25   66.0
# 366  65.0
# 225  65.0
# 40   65.0
# 351  64.0
# 433  64.0
# 385  63.0
# 221  63.0

# %% [markdown]
# # Kernel Density

# %%
df.bp.compare_kde_binn('age','survived')
